# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
dtype_dict = {'bathrooms':float, 'waterfront':int, 'sqft_above':int, 'sqft_living15':float, 'grade':int, 'yr_renovated':int, 'price':float, 'bedrooms':float, 'zipcode':str, 'long':float, 'sqft_lot15':float, 'sqft_living':float, 'floors':str, 'condition':int, 'lat':float, 'date':str, 'sqft_basement':int, 'yr_built':int, 'id':str, 'sqft_lot':int, 'view':int}
data = pd.read_csv('kc_house_data.csv', dtype = dtype_dict)

data.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#          waterfront          view     condition         grade    sqft_above  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       0.007542      0.234303      3.409430      7.656873   1788.390691
# ...

# %%
data['constant'] = 1
X = data[['constant', 'bedrooms', 'bathrooms', 'sqft_living']]
X.head()
y = data['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
class LinearRegression:
    def __init__(self, learning_rate=0.01,n_iteration=10000):
        self.learning_rate = learning_rate
        self.n_iterations = n_iterations
        self.weights, self.bias = None, None
        self.loss = []
    
    @staticmethod
    def _mean_square_error(y, y_hat):
        error = 0
        for i in range(len(y)):
            error += (y[i] - y_hat[i]) ** 2
        return error / len(y)
    
    def fit(self, x, y):
        # 1, init weights and bias to zeros
        self.weights = np.zeros(X.shape[1])
        self.bias = 0
        
        # 2, perform Gradient Descent
        for i in range(self.n_iterations):
            # Line equation
            y_hat = np.dot(X, self.weights) + self.bias
            loss = self._mean_square_error(y, y_hat)
            self.loss.append(loss)
            
            # Calculate derivatives
            partial_w = (1 / X.shape[0]) * (2 * np.dot(X.T, (y_hat - y)))
            partial_d = (1 / X.shape[0]) * (2 * np.sum(y_hat - y)
            
            # Update the coefficients
            self.weights -= self.learning_rate * partial_w
            self.bias -= self.learning_rate * partial_d
            
    def predict(self, X):
        return np.dot(X, self.weights) + self.bias
# Out:
#   File "C:\Users\Admin\AppData\Local\Temp/ipykernel_5588/4125675991.py", line 29
#     partial_d = (1 / X.shape[0]) * (2 * np.sum(y)hat - y)
#                                                  ^
# SyntaxError: invalid syntax

# %%
# Out:
#   File "C:\Users\Admin\AppData\Local\Temp/ipykernel_14676/1956758345.py", line 2
#     [your code here]
#           ^
# SyntaxError: invalid syntax

# %%
# Out:
#   File "C:\Users\Admin\AppData\Local\Temp/ipykernel_14676/3898952640.py", line 2
#     [your code here]
#           ^
# SyntaxError: invalid syntax

# %%
# Out:
#   File "C:\Users\Admin\AppData\Local\Temp/ipykernel_14676/890040960.py", line 18
#     gradient_magnitude = sqrt(gradient_sum_squares)
#     ^
# IndentationError: expected an indented block
