# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import math

# %%
dtype_dict = {'bathrooms':float, 'waterfront':int, 'sqft_above':int, 'sqft_living15':float, 'grade':int, 'yr_renovated':int, 'price':float, 'bedrooms':float, 'zipcode':str, 'long':float, 'sqft_lot15':float, 'sqft_living':float, 'floors':str, 'condition':int, 'lat':float, 'date':str, 'sqft_basement':int, 'yr_built':int, 'id':str, 'sqft_lot':int, 'view':int}
data = pd.read_csv('kc_house_data.csv', dtype = dtype_dict)

data.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#          waterfront          view     condition         grade    sqft_above  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       0.007542      0.234303      3.409430      7.656873   1788.390691
# ...

# %%
data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0       3.0       1.00
# 1      6414100192  20141209T000000  538000.0       3.0       2.25
# 2      5631500400  20150225T000000  180000.0       2.0       1.00
# 3      2487200875  20141209T000000  604000.0       4.0       3.00
# 4      1954400510  20150218T000000  510000.0       3.0       2.00
# ...           ...              ...       ...       ...        ...
# 21608  0263000018  20140521T000000  360000.0       3.0       2.50
# 21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610  1523300141  20140623T000000  402101.0       2.0       0.75
# 21611  0291310100  20150116T000000  400000.0       3.0       2.50
# 21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
#        sqft_living  sqft_lot floors  waterfront  view  ...  grade  sqft_above  \
# 0           1180.0      5650      1           0     0  ...      7        1180
# ...

# %%
data['constant'] = 1
data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0       3.0       1.00
# 1      6414100192  20141209T000000  538000.0       3.0       2.25
# 2      5631500400  20150225T000000  180000.0       2.0       1.00
# 3      2487200875  20141209T000000  604000.0       4.0       3.00
# 4      1954400510  20150218T000000  510000.0       3.0       2.00
# ...           ...              ...       ...       ...        ...
# 21608  0263000018  20140521T000000  360000.0       3.0       2.50
# 21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610  1523300141  20140623T000000  402101.0       2.0       0.75
# 21611  0291310100  20150116T000000  400000.0       3.0       2.50
# 21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
#        sqft_living  sqft_lot floors  waterfront  view  ...  sqft_above  \
# 0           1180.0      5650      1           0     0  ...        1180
# ...

# %%
data["sqft_living"] = data["sqft_living"] / 1000
features = data[['constant', 'bedrooms', 'bathrooms', 'sqft_living']]
output = data['price'] / 100000
features, output
# Out:
# (       constant  sqft_living
#  0             1      0.00118
#  1             1      0.00257
#  2             1      0.00077
#  3             1      0.00196
#  4             1      0.00168
#  ...         ...          ...
#  21608         1      0.00153
#  21609         1      0.00231
#  21610         1      0.00102
#  21611         1      0.00160
#  21612         1      0.00102
#
#  [21613 rows x 2 columns],
#  0        2.21900
#  1        5.38000
#  2        1.80000
#  3        6.04000
#  4        5.10000
#            ...
#  21608    3.60000
#  21609    4.00000
#  21610    4.02101
#  21611    4.00000
#  21612    3.25000
#  Name: price, Length: 21613, dtype: float64)

# %%
def predict_outcome(feature_matrix, weights):
    predictions = np.dot(feature_matrix, weights)
    return(predictions)

# %%
def feature_derivative(errors, feature):
    derivative = 2 * np.dot(errors, feature)
    return(derivative)

# %%
feature_name = ['constant', 'bedrooms', 'bathrooms', 'sqft_living']
def regression_gradient_descent(feature_matrix, output, initial_weights, step_size, tolerance):
    converged = False
    weights = np.array(initial_weights)
    while not converged:
        # compute the predictions based on feature_matrix and weights:
        predictions = predict_outcome(feature_matrix, weights)
        # compute the errors as predictions - output:
        errors = np.absolute(predictions - output)
        gradient_sum_squares = 0 # initialize the gradient
        # while not converged, update each weight individually:
        for i in range(len(weights)):
            # Recall that feature_matrix[:, i] is the feature column associated with weights[i]
            # compute the derivative for weight[i]:
            derivative = feature_derivative(errors, feature_matrix[feature_name[i]])
            # add the squared derivative to the gradient magnitude
            gradient_sum_squares += np.square(derivative)
            # update the weight based on step size and derivative:
            weights[i] = step_size * derivative
#             print(i, feature_name[i], weights[i], derivative)
#             print(weights)
        gradient_magnitude = math.sqrt(gradient_sum_squares)
        print(gradient_magnitude)
        if gradient_magnitude < tolerance:
            converged = True
    return(weights)

# %%
weights = regression_gradient_descent(features, output, [0, 0], 0.05, 0.01)
print(weights)
# Out:
# [-116729.25008       -293.94407547]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13160/3385757012.py in <module>
# ----> 1 weights = regression_gradient_descent(features, output, [0, 0], 0.05, 0.01)
#       2 print(weights)
#
# ~\AppData\Local\Temp/ipykernel_13160/3298847095.py in regression_gradient_descent(feature_matrix, output, initial_weights, step_size, tolerance)
#      10         for i in range(len(weights)):
#      11
# ---> 12             weights[i] = weights[i] - ((step_size / m) * np.dot(errors, feature_matrix))
#      13         if gradient_magnitude < tolerance:
#      14             converged = True
#
# ...
